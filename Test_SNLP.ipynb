# %% [markdown]
# # Notebook Overview
#
# This notebook provides an faster testing interface.
#
# It includes steps to
#  - Check GPU availability
#  - Set up the environment,
#  - Define helper functions,
#  - Run tests with a given **id** and **context_type**.
#
# The results are saved for further analysis.
#
# *Make sure to select the created `venv` as your kernel.*
#
# If there are any errors while running the tests, restart the the notebook, and run again.

# %% [markdown]
# ## Check GPU Availability
# Run this cell to check if there is free space on the gpu.
#
# If the **free space** is not close to the **total space** then someone else is probably using the machine.
#
# You can check the active processes bu running `nvidia-smi` in the terminal.

# %%
import subprocess

def get_gpu_memory():
    result = subprocess.run(
        ['nvidia-smi', '--query-gpu=memory.free,memory.total', '--format=csv,nounits,noheader'],
        stdout=subprocess.PIPE, text=True
    )
    lines = result.stdout.strip().split('\n')
    for i, line in enumerate(lines):
        free, total = map(int, line.split(','))
        print(f"GPU {i}: {free / 1024: .4} GiB free / {total / 1024: .4} GiB total")

get_gpu_memory()

# %% [markdown]
# ## Setup
# The code below imports necessary modules, defines directory paths, and sets the Hugging Face cache path.
#
# **No need to modify this.**

# %%
import os
import sys
import json
from pathlib import Path

PROJECT_DIR = Path.cwd()
HAYSTACK_DIR = PROJECT_DIR / "haystack"
RELEVANT_DIR = HAYSTACK_DIR / "relevant"
IRRELAVANT_DIR = HAYSTACK_DIR / "irrelevant"
MISLEADING_IN_RELEVANT_DIR = HAYSTACK_DIR / "misleading_in_relevant"
MISLEADING_IN_IRRELEVANT_DIR = HAYSTACK_DIR / "misleading_in_irrelevant"

sys.path.append(str(PROJECT_DIR))

with open(HAYSTACK_DIR / "needles.json", "r") as f:
    NEEDLES_DATA = json.load(f)

# This sets the Hugging Face cache path. Make sure this directory exists. If not, refer to the README.
os.environ['HF_HOME'] = '.cache/hf_with_quota'

# %% [markdown]
# ## Helper Functions

# %%
from transformers import AutoTokenizer

def load_text(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

def insert_strings_at_sentence_breaks(text, insert_strings, context_length, tokenizer):
    # Step 1: Tokenize and truncate
    tokens = tokenizer.encode(text, add_special_tokens=False)[:context_length]
    
    # Step 2: Detect sentence breaks by decoding each token
    sentence_break_indices = [
        i for i, tok in enumerate(tokens)
        if tokenizer.decode([tok]).strip().endswith((".", "!", "?"))
    ]

    if len(sentence_break_indices) < len(insert_strings):
        raise ValueError(f"Only {len(sentence_break_indices)} sentence breaks found, "
                         f"but {len(insert_strings)} insertions requested.")

    # Step 3: Compute evenly spaced sentence break positions
    step = len(sentence_break_indices) // (len(insert_strings) + 1)
    insert_positions = [sentence_break_indices[(i + 1) * step] + 1 for i in range(len(insert_strings))]

    # Step 4: Insert insert_strings as tokens
    for pos, insert_str in reversed(list(zip(insert_positions, insert_strings))):
        insert_tokens = tokenizer.encode(insert_str, add_special_tokens=False)
        tokens[pos:pos] = insert_tokens

    return tokenizer.decode(tokens)


def insert_misleading_statements(filepath, insert_strings, context_length, output_path):
    """
    Insert misleading statements into the text at sentence breaks.
    Evenly distribute the misleading statements across the text within the context length.
    """
    tokenizer = AutoTokenizer.from_pretrained("yaofu/llama-2-7b-80k")

    full_text = load_text(filepath)
    modified_text = insert_strings_at_sentence_breaks(full_text, insert_strings, context_length, tokenizer)

    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(modified_text)

    print(f"✅ Output saved to {output_path}")

# %%
from argparse import Namespace

def get_haystack_file(item, context_type, with_misleading, context_length):
    """
    Get the haystack file for the given item and context type.
    Arguments:
        item (dict): The item to process.
        context_type (str): The type of context ("relevant" or "irrelevant").
        with_misleading (bool): Whether to include misleading information.
    Returns:
        str: The path to the haystack file.
    """

    if context_type == "relevant":
        original_dir = RELEVANT_DIR
        original_file = item["context_relevant"]  # Original file without misleading info
        misleading_dir = MISLEADING_IN_RELEVANT_DIR  # Output dir for the misleading file
    elif context_type == "irrelevant":
        original_dir = IRRELAVANT_DIR
        original_file = item["context_irrelevant"]
        misleading_dir = MISLEADING_IN_IRRELEVANT_DIR
    else:
        raise ValueError(f"Unknown context_type: {context_type}")

    if with_misleading:
        haystack_file = misleading_dir / original_file
        insert_misleading_statements(
            filepath=original_dir / original_file,           # Path to the original context file
            insert_strings=item["statements_misleading"],    # List of misleading statements
            context_length=context_length,                   # Max context length for insertion
            output_path=haystack_file                        # Output path for the processed file
        )
    else:
        haystack_file = original_dir / original_file

    return haystack_file

def get_args(id, context_type, with_misleading, data=NEEDLES_DATA):
    """
    Get the arguments for the given id and context type.
    Arguments:
        id (int): The id of the item.
        context_type (str): The type of context ("relevant" or "irrelevant").
        data (list): The list of data items.
    Returns:
        Namespace: The arguments for the given id and context type.
    """

    context_length_max = 5000
    
    # find the item with the given id
    item = next(item for item in data if item["id"] == id)

    # get the haystack file for the given item and context type
    haystack_file = get_haystack_file(item, context_type, with_misleading, context_length_max)

    args = Namespace(
        model_name = "yaofu/llama-2-7b-80k",
        model_name_suffix = ( f"{context_type}_id_{item['id']}" if not with_misleading 
                             else f"{context_type}_id_{item['id']}_misleading"), # suffix used to name the results files,
        model_provider = "LLaMA",

        context_lengths_min = 0, # min context length
        context_lengths_max = context_length_max, # max context length
        context_lengths_num_intervals = 10, # number of intervals for context lengths

        document_depth_percent_intervals = 10, # number of intervals for document depth

        needle = item["needle"],
        real_needle = item["real_needle"],
        retrieval_question = item["question"],
        haystack_file = haystack_file,
    )

    return args

# %% [markdown]
# ## Runing the Tests

# %% [markdown]
# ### Set up the test object:
# Specify the **id** and the **context_type** in the `get_args` function.
#
# The notebook currently supports only individual testing for relevant and irrelevant context.
#
# The code for testing with misleading context will be added soon.

# %%
from retrieval_head_detection import LLMNeedleHaystackTester as RetrievalHeads

# Get the arguments for the given id and context type
args = get_args(id=44, context_type="relevant", with_misleading=True)

# Create the Tester object.
rh = RetrievalHeads(**vars(args))

# %% [markdown]
# ### Start the Test
#
# Running the test will save:
#
# - **Contexts** → Given to the model per context length/depth
#   → `contexts/{model_name}_{context_type}_id_{id}`
#
# - **Results** → Model outputs per context length/depth
#   → `results/graph/{model_name}_{context_type}_id_{id}`
#
# **Example**:
# `results/graph/llama-2-7b-80k_relevant_id_44/`
#
# Each test should take <=5 minutes. It sometimes uses the CPU instead of the GPU, if it is taking longer to finish, then restart the notebook and run again.

# %%
rh.start_test()
# Out:
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 10, Min: 0%, Max: 100%
# - Needle: There won't be a FIFA World Cup this year.
#
#
#
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 11%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_1100_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 22%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_2200_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_3300_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 44%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_4400_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 56%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_5600_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 67%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_6700_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 78%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_7800_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 89%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 11%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_1100_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 22%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_2200_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 33%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_3300_results.json
# insertion at 121
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 44%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_4400_results.json
# insertion at 121
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 56%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_5600_results.json
# insertion at 196
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 67%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_6700_results.json
# insertion at 264
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 78%
# Score: 60.0
# Response: The FIFA World Cup will not be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_7800_results.json
# insertion at 293
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 89%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 11%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_1100_results.json
# insertion at 196
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 22%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_2200_results.json
# insertion at 293
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 33%
# Score: 70.0
# Response: The FIFA World Cup will not be hosted this year. The FIFA World Cup is a quadrennial international football tournament contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA),
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_3300_results.json
# insertion at 365
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['19-15'], ['17-22'], ['8-26'], ['11-2'], ['6-30'], ['12-26'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1111 tokens
# Depth: 44%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_4400_results.json
# insertion at 485
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['19-15'], ['8-26'], ['11-2'], ['6-30'], ['12-26'], ['21-30'], ['28-14'], ['24-11'], ['24-29'], ['19-12'], ['21-4'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1111 tokens
# Depth: 56%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_5600_results.json
# insertion at 584
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['19-15'], ['8-26'], ['11-2'], ['6-30'], ['12-26'], ['21-30'], ['28-14'], ['24-11'], ['24-29'], ['30-14'], ['19-12'], ['21-4'], ['24-30'], ['25-3'], ['29-21']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1111 tokens
# Depth: 67%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_6700_results.json
# insertion at 695
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['6-30'], ['12-26'], ['21-30'], ['28-14'], ['24-11'], ['24-29'], ['30-14'], ['19-12'], ['21-4'], ['24-30'], ['25-3'], ['29-21']]
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 78%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. The first international tournament for nations, the inaugural British Home Championship, took place in 1884 and included games between England, Scotland, Wales, and Ireland. As football grew
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_7800_results.json
# insertion at 730
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['6-30'], ['12-26'], ['21-30'], ['28-14'], ['24-11'], ['24-29'], ['30-14'], ['19-12'], ['21-4'], ['24-30'], ['25-3'], ['29-21']]
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 89%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. As football grew in popularity in other parts of the world at the start of the 20th century, it was held as a demonstration sport with no medals awarded at the
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['12-26'], ['21-30'], ['6-30'], ['28-14'], ['24-11'], ['24-29'], ['30-14'], ['24-30'], ['25-3'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.5 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_0_results.json
# insertion at 121
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 11%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_1100_results.json
# insertion at 293
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['12-26'], ['21-30'], ['6-30'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 22%
# Score: 70.0
# Response: The FIFA World Cup will not be held this year. The FIFA World Cup is a quadrennial international football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA),
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_2200_results.json
# insertion at 441
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['30-14'], ['24-30'], ['25-3'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. The other World Cup winners are Germany and Italy, with four titles each; Argentina, with three titles; France and inaugural winner Uruguay, each with two titles; and England and Spain
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_3300_results.json
# insertion at 610
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-11'], ['24-29'], ['30-14'], ['24-30'], ['25-3'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 1667 tokens
# Depth: 44%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year. The 2026 FIFA World Cup will be jointly hosted by Canada, Mexico, and the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_4400_results.json
# insertion at 814
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['6-30'], ['12-26'], ['28-14'], ['24-29'], ['24-11'], ['30-14'], ['21-4'], ['24-30'], ['25-3'], ['19-12'], ['29-21']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 56%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_5600_results.json
# insertion at 974
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 67%
# Score: 50.0
# Response: It won't be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_6700_results.json
# insertion at 1130
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 78%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_7800_results.json
# insertion at 1265
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['6-30'], ['12-26'], ['28-14'], ['24-29'], ['24-11'], ['30-14'], ['21-4'], ['24-30'], ['25-3'], ['29-26'], ['19-12']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 89%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. This paved the way for the world's first intercontinental football competition for nations, at the 1920 Summer Olympics, contested by Egypt and 13 European
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['30-14'], ['24-30'], ['25-3'], ['21-4'], ['21-16'], ['29-26']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_0_results.json
# insertion at 196
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 11%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_1100_results.json
# insertion at 441
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 22%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_2200_results.json
# insertion at 652
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['30-14'], ['24-11'], ['7-12'], ['21-4'], ['21-16'], ['24-30'], ['25-3']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_3300_results.json
# insertion at 875
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['7-12'], ['30-14'], ['24-11'], ['19-12'], ['21-4'], ['21-16'], ['17-16']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 44%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_4400_results.json
# insertion at 1109
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 56%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_5600_results.json
# insertion at 1333
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 67%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_6700_results.json
# insertion at 1566
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 78%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_7800_results.json
# insertion at 1779
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 89%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['7-12'], ['24-11'], ['30-14'], ['21-16'], ['19-12'], ['21-4'], ['24-30']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 0.0
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_0_results.json
# insertion at 264
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 11%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_1100_results.json
# insertion at 538
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['7-12'], ['24-11'], ['30-14'], ['21-16'], ['19-12'], ['21-4'], ['24-30']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 22%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_2200_results.json
# insertion at 814
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['11-2'], ['8-26'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['28-14'], ['30-14'], ['24-11'], ['21-16'], ['21-4'], ['14-18'], ['19-12']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_3300_results.json
# insertion at 1109
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 44%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_4400_results.json
# insertion at 1427
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 56%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_5600_results.json
# insertion at 1705
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 67%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_6700_results.json
# insertion at 1963
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 78%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_7800_results.json
# insertion at 2220
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 89%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['11-2'], ['8-26'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['28-14'], ['30-14'], ['24-11'], ['21-16'], ['21-4'], ['24-30'], ['25-3']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_0_results.json
# insertion at 342
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['28-14'], ['21-16'], ['30-14'], ['24-11'], ['14-18'], ['19-12'], ['21-4']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 3333 tokens
# Depth: 11%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. The competition is scheduled to expand to 48 teams, starting with the 2026 World Cup.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_1100_results.json
# insertion at 652
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['28-14'], ['21-16'], ['30-14'], ['24-11'], ['14-18'], ['21-4'], ['17-16']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 22%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_2200_results.json
# insertion at 991
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['19-15'], ['21-30'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['28-14'], ['21-16'], ['30-14'], ['24-11'], ['14-18'], ['17-16'], ['21-4']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_3300_results.json
# insertion at 1333
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['21-16'], ['30-14'], ['24-11'], ['14-18'], ['17-16'], ['19-12']]
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 44%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. Those were also the first two open world championships, as 1924 was the start of FIFA's professional era, and is the reason why Uruguay is allowed to wear
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_4400_results.json
# insertion at 1743
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['28-14'], ['30-14'], ['24-11'], ['17-16'], ['14-18'], ['19-12']]
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 56%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. After the creation of the World Cup, FIFA and the IOC disagreed over the status of amateur players; football was dropped from the 1932 Summer Olympics. After the
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_5600_results.json
# insertion at 2058
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['28-14'], ['30-14'], ['17-16'], ['24-11'], ['14-18'], ['19-12']]
# -- Test Summary --
# Duration: 3.6 seconds
# Context: 3333 tokens
# Depth: 67%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. Uruguay won the tournament again after defeating the host nation Brazil, in the match called "Maracanazo" (Portuguese: Maracanaço).
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_6700_results.json
# insertion at 2361
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['17-16'], ['14-18'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 78%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. Since then, teams from these regions have enjoyed more success, with several having reached the quarter-finals: Mexico, quarter-finalists in 1986; Cameroon
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_7800_results.json
# insertion at 2743
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 89%
# Score: 50.0
# Response: It won't be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['14-18'], ['17-16'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 0.0
# Response: In the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_0_results.json
# insertion at 365
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3889 tokens
# Depth: 11%
# Score: 10.0
# Response: It will be held in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_1100_results.json
# insertion at 730
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 3889 tokens
# Depth: 22%
# Score: 0.0
# Response: In Saudi Arabia, in 2022.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_2200_results.json
# insertion at 1212
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 33%
# Score: 50.0
# Response: It won't be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_3300_results.json
# insertion at 1616
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 44%
# Score: 10.0
# Response: It will be held in the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_4400_results.json
# insertion at 2058
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 3889 tokens
# Depth: 56%
# Score: 0.0
# Response: In Saudi Arabia, in 2022.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_5600_results.json
# insertion at 2361
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3889 tokens
# Depth: 67%
# Score: 30.0
# Response: It will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_6700_results.json
# insertion at 2854
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 78%
# Score: 10.0
# Response: It will be held in the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_7800_results.json
# insertion at 3259
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 3889 tokens
# Depth: 89%
# Score: 20.0
# Response: Not this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['14-18'], ['17-16'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_0_results.json
# insertion at 441
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['28-14'], ['30-14'], ['14-18'], ['17-16'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 4444 tokens
# Depth: 11%
# Score: 60.0
# Response: The FIFA World Cup is a football tournament that is held every four years. The next FIFA World Cup will be held in 2026.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_1100_results.json
# insertion at 916
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 22%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_2200_results.json
# insertion at 1374
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['21-16'], ['28-14'], ['17-16'], ['30-14'], ['14-18'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 33%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_3300_results.json
# insertion at 1840
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 44%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_4400_results.json
# insertion at 2361
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['19-15'], ['7-12'], ['12-26'], ['24-29'], ['6-30'], ['21-16'], ['17-16'], ['30-14'], ['28-14'], ['14-18'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 4.2 seconds
# Context: 4444 tokens
# Depth: 56%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. Since then, teams from these regions have enjoyed more success, with several having reached the quarter-finals: Mexico, quarter-finalists in 1986; Cameroon
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_5600_results.json
# insertion at 2797
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 4444 tokens
# Depth: 67%
# Score: 50.0
# Response: It won't be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_6700_results.json
# insertion at 3295
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['17-22'], ['7-4'], ['8-26'], ['11-2'], ['7-12'], ['21-30'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['21-16'], ['17-16'], ['30-14'], ['28-14'], ['14-18'], ['16-1'], ['24-11']]
# -- Test Summary --
# Duration: 4.2 seconds
# Context: 4444 tokens
# Depth: 78%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year. At the time, FIFA president Sepp Blatter announced he would relinquish his position in February 2016. The hosting rights for the FIFA World Cup have been awarded
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_7800_results.json
# insertion at 3720
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['17-22'], ['7-4'], ['8-26'], ['11-2'], ['7-12'], ['21-30'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['21-16'], ['17-16'], ['30-14'], ['14-18'], ['28-14'], ['16-1'], ['24-11']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 89%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['17-22'], ['7-4'], ['8-26'], ['11-2'], ['7-12'], ['21-30'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['21-16'], ['17-16'], ['30-14'], ['14-18'], ['28-14'], ['16-1'], ['24-11']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_0_results.json
# insertion at 519
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 11%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_1100_results.json
# insertion at 1031
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 22%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_2200_results.json
# insertion at 1566
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 33%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_3300_results.json
# insertion at 2058
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 44%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_4400_results.json
# insertion at 2636
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 56%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_5600_results.json
# insertion at 3195
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 67%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_6700_results.json
# insertion at 3720
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 78%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_7800_results.json
# insertion at 4220
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 89%
# Score: 40.0
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_8900_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['17-22'], ['7-4'], ['8-26'], ['11-2'], ['21-30'], ['7-12'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['21-16'], ['17-16'], ['30-14'], ['14-18'], ['28-14'], ['24-11'], ['16-1']]
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 60.0
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_10000_results.json
