# %% [markdown]
# # Notebook Overview
#
# This notebook provides an faster testing interface.
#
# It includes steps to
#  - Check GPU availability
#  - Set up the environment,
#  - Define helper functions,
#  - Run tests with a given **id** and **context_type**.
#
# The results are saved for further analysis.
#
# *Make sure to select the created `venv` as your kernel.*
#
# If there are any errors while running the tests, restart the the notebook, and run again.

# %% [markdown]
# ## Check GPU Availability
# Run this cell to check if there is free space on the gpu.
#
# If the **free space** is not close to the **total space** then someone else is probably using the machine.
#
# You can check the active processes bu running `nvidia-smi` in the terminal.

# %%
import torch

def get_gpu_memory_torch():
    if torch.cuda.is_available():
        for i in range(torch.cuda.device_count()):
            free_mem = torch.cuda.mem_get_info(i)[0] / 1024**3
            total_mem = torch.cuda.get_device_properties(i).total_memory / 1024**3
            print(f"GPU {i}: {free_mem:.4f} GiB free / {total_mem:.4f} GiB total")
    else:
        print("No CUDA-compatible GPU detected.")

get_gpu_memory_torch()
# Out:
# GPU 0: 23.2824 GiB free / 23.5766 GiB total

# %% [markdown]
# ## Setup
# The code below imports necessary modules, defines directory paths, and sets the Hugging Face cache path.
#
# **No need to modify this.**

# %%
import os
import sys
import json
from pathlib import Path

PROJECT_DIR = Path.cwd()
HAYSTACK_DIR = PROJECT_DIR / "haystack"
RELEVANT_DIR = HAYSTACK_DIR / "relevant"
IRRELAVANT_DIR = HAYSTACK_DIR / "irrelevant"
MISLEADING_IN_RELEVANT_DIR = HAYSTACK_DIR / "misleading_in_relevant"
MISLEADING_IN_IRRELEVANT_DIR = HAYSTACK_DIR / "misleading_in_irrelevant"

sys.path.append(str(PROJECT_DIR))

with open(HAYSTACK_DIR / "needles.json", "r") as f:
    NEEDLES_DATA = json.load(f)

# This sets the Hugging Face cache path. Make sure this directory exists. If not, refer to the README.
os.environ['HF_HOME'] = '.cache/hf_with_quota'

# %% [markdown]
# ## Helper Functions

# %%
from transformers import AutoTokenizer

def load_text(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

def insert_strings_at_sentence_breaks(text, insert_strings, context_length, tokenizer):
    # Step 1: Tokenize and truncate
    tokens = tokenizer.encode(text, add_special_tokens=False)[:context_length]
    
    # Step 2: Detect sentence breaks by decoding each token
    sentence_break_indices = [
        i for i, tok in enumerate(tokens)
        if tokenizer.decode([tok]).strip().endswith((".", "!", "?"))
    ]

    if len(sentence_break_indices) < len(insert_strings):
        raise ValueError(f"Only {len(sentence_break_indices)} sentence breaks found, "
                         f"but {len(insert_strings)} insertions requested.")

    # Step 3: Compute evenly spaced sentence break positions
    step = len(sentence_break_indices) // (len(insert_strings) + 1)
    insert_positions = [sentence_break_indices[(i + 1) * step] + 1 for i in range(len(insert_strings))]

    # Step 4: Insert insert_strings as tokens
    for pos, insert_str in reversed(list(zip(insert_positions, insert_strings))):
        insert_tokens = tokenizer.encode(insert_str, add_special_tokens=False)
        tokens[pos:pos] = insert_tokens

    return tokenizer.decode(tokens)


def insert_misleading_statements(filepath, insert_strings, context_length, output_path):
    """
    Insert misleading statements into the text at sentence breaks.
    Evenly distribute the misleading statements across the text within the context length.
    """
    tokenizer = AutoTokenizer.from_pretrained("yaofu/llama-2-7b-80k")

    full_text = load_text(filepath)
    modified_text = insert_strings_at_sentence_breaks(full_text, insert_strings, context_length, tokenizer)

    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(modified_text)

    print(f"✅ Output saved to {output_path}")

# %%
from argparse import Namespace

def get_haystack_file(item, context_type, with_misleading, context_length):
    """
    Get the haystack file for the given item and context type.
    Arguments:
        item (dict): The item to process.
        context_type (str): The type of context ("relevant" or "irrelevant").
        with_misleading (bool): Whether to include misleading information.
    Returns:
        str: The path to the haystack file.
    """

    if context_type == "relevant":
        original_dir = RELEVANT_DIR
        original_file = item["context_relevant"]  # Original file without misleading info
        misleading_dir = MISLEADING_IN_RELEVANT_DIR  # Output dir for the misleading file
    elif context_type == "irrelevant":
        original_dir = IRRELAVANT_DIR
        original_file = item["context_irrelevant"]
        misleading_dir = MISLEADING_IN_IRRELEVANT_DIR
    else:
        raise ValueError(f"Unknown context_type: {context_type}")

    if with_misleading:
        haystack_file = misleading_dir / original_file
        insert_misleading_statements(
            filepath=original_dir / original_file,           # Path to the original context file
            insert_strings=item["statements_misleading"],    # List of misleading statements
            context_length=context_length,                   # Max context length for insertion
            output_path=haystack_file                        # Output path for the processed file
        )
    else:
        haystack_file = original_dir / original_file

    return haystack_file

def get_args(id, context_type, with_misleading, data=NEEDLES_DATA):
    """
    Get the arguments for the given id and context type.
    Arguments:
        id (int): The id of the item.
        context_type (str): The type of context ("relevant" or "irrelevant").
        with_misleading (bool): Whether to include misleading information.
        data (list): The list of data items.
    Returns:
        Namespace: The arguments for the given id and context type.
    """

    context_length_max = 5000
    
    # find the item with the given id
    item = next(item for item in data if item["id"] == id)

    # get the haystack file for the given item and context type
    haystack_file = get_haystack_file(item, context_type, with_misleading, context_length_max)

    args = Namespace(
        model_name = "yaofu/llama-2-7b-80k",
        model_name_suffix = ( f"{context_type}_id_{item['id']}" if not with_misleading 
                             else f"{context_type}_id_{item['id']}_misleading"), # suffix used to name the results files,
        model_provider = "LLaMA",

        context_lengths_min = 0, # min context length
        context_lengths_max = context_length_max, # max context length
        context_lengths_num_intervals = 10, # number of intervals for context lengths

        document_depth_percent_intervals = 5, # number of intervals for document depth

        needle = item["needle"],
        real_needle = item["real_needle"],
        retrieval_question = item["question"],
        haystack_file = haystack_file,
    )

    return args

# %%
import gc
import torch
from retrieval_head_detection import LLMNeedleHaystackTester as RetrievalHeads

def cleanup(tester: RetrievalHeads):
    del tester.model_to_test
    del tester.testing_results
    del tester.head_counter
    del tester
    
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

def run_test(args):
    tester = RetrievalHeads(**vars(args))
    tester.start_test()
    cleanup(tester)

# %% [markdown]
# ## Runing the Tests

# %% [markdown]
# ### Set up the test object:
# Specify the **id** and the **context_type** in the `get_args` function.
#
# If `with_misleading` is True, then misleading statements are added to the specified `context_type` file.

# %% [markdown]
# ### Start the Test
#
# Running the test will save:
#
# - **Contexts** → Given to the model per context length/depth
#   → `contexts/{model_name}_{context_type}_id_{id}`
#
# - **Results** → Model outputs per context length/depth
#   → `results/graph/{model_name}_{context_type}_id_{id}`
#
# **Example**:
# `results/graph/llama-2-7b-80k_relevant_id_44/`
#
# Each test should take <=5 minutes. It sometimes uses the CPU instead of the GPU, if it is taking longer to finish, then restart the notebook and run again.

# %%
# Get the arguments for the given id and context type
args = get_args(id=44, context_type="relevant", with_misleading=True)
run_test(args)

args = get_args(id=44, context_type="irrelevant", with_misleading=True)
run_test(args)

args = get_args(id=44, context_type="relevant", with_misleading=False)
run_test(args)

args = get_args(id=44, context_type="irrelevant", with_misleading=False)
run_test(args)
# Out:
# ✅ Output saved to /cs/student/projects1/2021/aagarwal/SNLP_Project/haystack/misleading_in_relevant/44.txt
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# The model was loaded with use_flash_attention_2=True, which is deprecated and may be removed in a future release. Please use `attn_implementation="flash_attention_2"` instead.
# LlamaForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: There won't be a FIFA World Cup this year.
#
#
#
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_2500_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_5000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_0_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_2500_results.json
# insertion at 121
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_5000_results.json
# insertion at 238
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_556_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_0_results.json
# insertion at 196
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_2500_results.json
# insertion at 441
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 73.9825963973999
# Response: The FIFA World Cup will not be hosted this year. The FIFA World Cup is a quadrennial international football tournament contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA),
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_5000_results.json
# insertion at 652
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['6-30'], ['12-26'], ['28-14'], ['21-4'], ['24-29'], ['30-14'], ['19-12'], ['24-11'], ['24-30'], ['25-3'], ['29-21']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['21-4'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['29-21']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1111_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.5 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_0_results.json
# insertion at 342
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['21-4'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['29-21']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 75.37270784378052
# Response: The FIFA World Cup will not be held this year. The FIFA World Cup is a quadrennial international football tournament contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA),
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_2500_results.json
# insertion at 695
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['8-26'], ['11-2'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['21-4'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['29-21']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 73.79819750785828
# Response: The FIFA World Cup will not be hosted this year. The FIFA World Cup is a quadrennial international football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA),
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_5000_results.json
# insertion at 1058
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['17-22'], ['19-15'], ['8-26'], ['11-2'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['30-14'], ['19-12'], ['21-4'], ['24-30'], ['25-3'], ['29-21']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 80.02992272377014
# Response: There won't be a FIFA World Cup this year. The competition is sometimes described as The First World Cup, and featured the most prestigious professional club sides from Italy, Germany and Switzerland, but the FA of England refused to be associated with
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['17-22'], ['19-15'], ['8-26'], ['11-2'], ['21-30'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['21-4'], ['21-16']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_1667_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_0_results.json
# insertion at 485
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_2500_results.json
# insertion at 991
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_5000_results.json
# insertion at 1492
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['21-30'], ['8-26'], ['11-2'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['19-12'], ['21-4'], ['21-16']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2222_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_0_results.json
# insertion at 610
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_2500_results.json
# insertion at 1265
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_5000_results.json
# insertion at 1895
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['19-15'], ['11-2'], ['21-30'], ['8-26'], ['12-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['21-4'], ['21-16'], ['19-12']]
# -- Test Summary --
# Duration: 3.0 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 78.37415933609009
# Response: There won't be a FIFA World Cup this year. The 1942 and 1946 competitions, which Germany and Brazil sought to host, were cancelled due to World War II.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['21-30'], ['11-2'], ['12-26'], ['8-26'], ['6-30'], ['28-14'], ['24-29'], ['24-11'], ['24-30'], ['25-3'], ['21-16'], ['30-14'], ['21-4'], ['14-18']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_2778_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_0_results.json
# insertion at 730
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['17-22'], ['19-15'], ['21-30'], ['11-2'], ['8-26'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['21-16'], ['24-11'], ['24-30'], ['25-3'], ['30-14'], ['7-12'], ['19-12']]
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 74.16788339614868
# Response: There won't be a FIFA World Cup this year. As football grew in popularity in other parts of the world at the start of the 20th century, it was held as a demonstration sport with no medals awarded at the
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_2500_results.json
# insertion at 1543
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['19-15'], ['21-30'], ['8-26'], ['11-2'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['28-14'], ['21-16'], ['30-14'], ['24-11'], ['24-30'], ['25-3'], ['19-12']]
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 57.5150191783905
# Response: There won't be a FIFA World Cup this year. As such, no European country pledged to send a team until two months before the start of the competition. Rimet eventually persuaded teams from Belgium, France, Romania,
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_5000_results.json
# insertion at 2300
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['21-30'], ['19-15'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['24-11'], ['24-30'], ['25-3'], ['14-18']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['21-30'], ['19-15'], ['8-26'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['24-30'], ['25-3'], ['14-18'], ['24-11']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3333_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 4.195231944322586
# Response: In the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_0_results.json
# insertion at 916
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 25.759023427963257
# Response: In Saudi Arabia, in 2022.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_2500_results.json
# insertion at 1818
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['21-30'], ['19-15'], ['8-26'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['24-30'], ['25-3'], ['14-18'], ['24-11']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 53.98586392402649
# Response: It won't be hosted this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_5000_results.json
# insertion at 2743
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['21-30'], ['19-15'], ['8-26'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['28-14'], ['24-30'], ['25-3'], ['14-18'], ['24-11']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 57.21930265426636
# Response: It will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['19-15'], ['21-30'], ['8-26'], ['11-2'], ['12-26'], ['6-30'], ['7-12'], ['24-29'], ['30-14'], ['28-14'], ['21-16'], ['14-18'], ['29-26'], ['25-3'], ['17-16']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_3889_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_0_results.json
# insertion at 1031
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_2500_results.json
# insertion at 2058
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_5000_results.json
# insertion at 3077
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['8-26'], ['21-30'], ['19-15'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['30-14'], ['21-16'], ['28-14'], ['17-16'], ['14-18'], ['29-26'], ['25-3']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['21-30'], ['8-26'], ['19-15'], ['11-2'], ['12-26'], ['7-12'], ['6-30'], ['24-29'], ['21-16'], ['30-14'], ['14-18'], ['28-14'], ['17-16'], ['25-3'], ['29-26']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_4444_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_0_results.json
# insertion at 1151
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_2500_results.json
# insertion at 2361
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_5000_results.json
# insertion at 3583
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['17-22'], ['19-15'], ['21-30'], ['8-26'], ['11-2'], ['12-26'], ['7-12'], ['24-29'], ['6-30'], ['21-16'], ['30-14'], ['14-18'], ['28-14'], ['25-3'], ['11-17'], ['17-16']]
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_44_misleading/llama-2-7b-80k_relevant_id_44_misleading_len_5000_depth_10000_results.json
# ✅ Output saved to /cs/student/projects1/2021/aagarwal/SNLP_Project/haystack/misleading_in_irrelevant/44.txt
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: There won't be a FIFA World Cup this year.
#
#
#
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_0_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_0_depth_2500_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_0_depth_5000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_0_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['17-22'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_0_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_556_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_556_depth_2500_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_556_depth_5000_results.json
# insertion at 237
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 45.10098695755005
# Response: The FIFA World Cup will be hosted in Qatar in 2022.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_556_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_556_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.4 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1111_depth_0_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.4 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1111_depth_2500_results.json
# insertion at 448
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['12-26'], ['21-30'], ['28-14'], ['19-12'], ['21-4'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['29-21'], ['29-26']]
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 57.30794072151184
# Response: The FIFA World Cup will not be held this year. The Premier League is a corporation managed by a chief executive, with member clubs acting as shareholders. The Premier League takes advantage of a £5 billion television rights deal, with Sky and
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1111_depth_5000_results.json
# insertion at 655
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1111_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['12-26'], ['21-30'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1111_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1667_depth_0_results.json
# insertion at 346
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1667_depth_2500_results.json
# insertion at 679
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 45.10098695755005
# Response: The FIFA World Cup will be hosted in Qatar in 2022.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1667_depth_5000_results.json
# insertion at 1062
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1667_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['21-30'], ['12-26'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_1667_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2222_depth_0_results.json
# insertion at 470
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2222_depth_2500_results.json
# insertion at 958
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2222_depth_5000_results.json
# insertion at 1485
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2222_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['21-30'], ['12-26'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2222_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 48.567262291908264
# Response: The FIFA World Cup will be hosted in Qatar this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2778_depth_0_results.json
# insertion at 614
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['21-30'], ['12-26'], ['17-22'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['19-12'], ['21-4'], ['29-21']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2778_depth_2500_results.json
# insertion at 1206
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['21-16'], ['19-12'], ['21-4']]
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 59.91191267967224
# Response: The FIFA World Cup will not be held this year. The Taylor Report on stadium safety standards, which proposed expensive upgrades to create all-seater stadiums in the aftermath of the Hillsborough disaster (between the fans of Liverpool
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2778_depth_5000_results.json
# insertion at 1882
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['6-9'], ['19-15'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['21-16'], ['31-16'], ['19-12'], ['21-4']]
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 60.74535846710205
# Response: The FIFA World Cup will not be held this year. The five clubs agreed with the suggestion and decided to press ahead with it; however, the league would have no credibility without the backing of the Football Association, and so David Dein of Ar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2778_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['21-16'], ['31-16'], ['19-12'], ['21-4']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_2778_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3333_depth_0_results.json
# insertion at 758
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3333_depth_2500_results.json
# insertion at 1542
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3333_depth_5000_results.json
# insertion at 2306
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3333_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['21-30'], ['17-22'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['21-16'], ['31-16'], ['13-11'], ['17-0']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3333_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3889_depth_0_results.json
# insertion at 875
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['24-11'], ['24-29'], ['21-16'], ['24-30'], ['25-3'], ['31-16'], ['13-11'], ['17-0']]
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3889_depth_2500_results.json
# insertion at 1836
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3889_depth_5000_results.json
# insertion at 2717
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['21-16'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['13-11'], ['17-0']]
# -- Test Summary --
# Duration: 3.9 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 68.90606880187988
# Response: The FIFA World Cup will not be held this year. It was originally scheduled to be held in 2022, but due to the COVID-19 pandemic, it was postponed to 2022.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3889_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['17-22'], ['21-30'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['21-16'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['12-16'], ['13-11']]
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_3889_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 45.17129063606262
# Response: The FIFA World Cup will be held in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_4444_depth_0_results.json
# insertion at 1015
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_4444_depth_2500_results.json
# insertion at 2042
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_4444_depth_5000_results.json
# insertion at 3094
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_4444_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['6-9'], ['21-30'], ['17-22'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['21-16'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['31-16'], ['13-11'], ['17-0']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_4444_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_5000_depth_0_results.json
# insertion at 1137
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_5000_depth_2500_results.json
# insertion at 2368
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_5000_depth_5000_results.json
# insertion at 3094
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_5000_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['7-4'], ['11-15'], ['19-15'], ['21-30'], ['6-9'], ['17-22'], ['12-26'], ['6-30'], ['8-26'], ['11-2'], ['28-14'], ['21-16'], ['24-11'], ['24-29'], ['24-30'], ['25-3'], ['13-11'], ['17-0'], ['17-13']]
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44_misleading/llama-2-7b-80k_irrelevant_id_44_misleading_len_5000_depth_10000_results.json
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# ...
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 71.18617296218872
# Response: There won't be a FIFA World Cup this year. Most games are played on weekend afternoons, with occasional weekday evening fixtures.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_1667_depth_2500_results.json
# insertion at 659
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['19-15'], ['21-30'], ['11-2'], ['6-30'], ['12-26'], ['28-14'], ['7-12'], ['24-29'], ['29-26'], ['30-14'], ['21-4'], ['24-11'], ['19-12'], ['24-30']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 61.63523197174072
# Response: There won't be a FIFA World Cup this year. For the 2023–24 season, the average Premier League match attendance was 38,375, second to the German Bundesliga's 3
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_1667_depth_5000_results.json
# insertion at 1042
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['19-15'], ['21-30'], ['11-2'], ['6-30'], ['12-26'], ['7-12'], ['28-14'], ['29-26'], ['24-29'], ['30-14'], ['21-4'], ['24-11'], ['19-12'], ['24-30']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 72.09935784339905
# Response: There won't be a FIFA World Cup this year. The Football League First Division, the top level of English football since 1888, was behind leagues such as Italy's Serie A and Spain's La Liga in attend
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_1667_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['7-4'], ['6-9'], ['8-26'], ['17-22'], ['19-15'], ['21-30'], ['11-2'], ['12-26'], ['6-30'], ['7-12'], ['28-14'], ['29-26'], ['24-29'], ['30-14'], ['21-4'], ['24-11'], ['24-30'], ['25-3']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_1667_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2222_depth_0_results.json
# insertion at 470
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 3.1 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 21.668049693107605
# Response: The Premier League is the most-watched sports league in the world, broadcast in 212 territories to 643 million homes, with a potential TV audience of 4.7 billion people. For the 202
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2222_depth_2500_results.json
# insertion at 995
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2222_depth_5000_results.json
# insertion at 1497
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 30.223888158798218
# Response: It will be hosted in the United States.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2222_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2222_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2778_depth_0_results.json
# insertion at 614
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['21-30'], ['19-15'], ['11-2'], ['7-12'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['29-26'], ['30-14'], ['21-4'], ['24-11'], ['21-16'], ['24-30']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2778_depth_2500_results.json
# insertion at 1265
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['21-30'], ['11-2'], ['7-12'], ['19-15'], ['12-26'], ['6-30'], ['24-29'], ['28-14'], ['29-26'], ['30-14'], ['21-4'], ['24-11'], ['21-16'], ['29-21']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2778_depth_5000_results.json
# insertion at 1894
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['11-2'], ['21-30'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['29-26'], ['28-14'], ['30-14'], ['21-4'], ['17-16'], ['28-6'], ['28-9']]
# -- Test Summary --
# Duration: 3.4 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 73.5211730003357
# Response: There won't be a FIFA World Cup this year. The FA did not have an amicable relationship with the Football League at the time and considered it a way to weaken the Football League's position. The FA released a report in
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2778_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['29-26'], ['28-14'], ['30-14'], ['21-4'], ['17-16'], ['21-16'], ['24-11']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_2778_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 24.295465648174286
# Response: Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3333_depth_0_results.json
# insertion at 738
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3333_depth_2500_results.json
# insertion at 1497
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3333_depth_5000_results.json
# insertion at 2299
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 34.99683737754822
# Response: It will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3333_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['21-30'], ['7-12'], ['19-15'], ['11-2'], ['12-26'], ['24-29'], ['6-30'], ['29-26'], ['28-14'], ['30-14'], ['21-4'], ['21-16'], ['24-11'], ['14-18']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3333_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3889_depth_0_results.json
# insertion at 855
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['12-26'], ['24-29'], ['6-30'], ['29-26'], ['28-14'], ['30-14'], ['21-4'], ['21-16'], ['24-11'], ['14-18']]
# -- Test Summary --
# Duration: 4.0 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 74.35961961746216
# Response: There won't be a FIFA World Cup this year. Seven have won the title: Manchester United (13), Manchester City (8), Chelsea (5), Arsenal (3), Blackburn Rovers (1), Leic
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3889_depth_2500_results.json
# insertion at 1837
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 4.0 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 38.134968280792236
# Response: It will not be held this year. The five clubs agreed with the suggestion and decided to press ahead with it; however, the league would have no credibility without the backing of the Football Association, and so David Dein of Arsenal held
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3889_depth_5000_results.json
# insertion at 2734
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['6-30'], ['29-26'], ['30-14'], ['28-14'], ['17-16'], ['21-16'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 4.0 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 66.79604053497314
# Response: There won't be a FIFA World Cup this year. Bolstered by this breakthrough, United immediately became the competition's dominant team, winning seven of the first nine trophies, two League and FA Cup 'doubles'
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3889_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['6-30'], ['29-26'], ['30-14'], ['21-16'], ['28-14'], ['17-16'], ['14-18'], ['21-4']]
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_3889_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_4444_depth_0_results.json
# insertion at 1042
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 24.189698696136475
# Response: England
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_4444_depth_2500_results.json
# insertion at 1973
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 45.17988562583923
# Response: The FIFA World Cup will be hosted in Qatar.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_4444_depth_5000_results.json
# insertion at 3000
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['6-30'], ['29-26'], ['30-14'], ['17-16'], ['21-16'], ['28-14'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_4444_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['7-4'], ['8-26'], ['17-22'], ['7-12'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['6-30'], ['29-26'], ['21-16'], ['30-14'], ['17-16'], ['28-14'], ['14-18'], ['24-30']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_4444_depth_10000_results.json
# insertion at 0
# There won't be a FIFA World Cup this year.
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 23.75866323709488
# Response: Qatar
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_5000_depth_0_results.json
# insertion at 1186
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['8-26'], ['7-4'], ['7-12'], ['17-22'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['17-16'], ['6-30'], ['21-16'], ['29-26'], ['30-14'], ['14-18'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 4.4 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 69.98887658119202
# Response: There won't be a FIFA World Cup this year. The Taylor Report on stadium safety standards, which proposed expensive upgrades to create all-seater stadiums in the aftermath of the Hillsborough disaster (between the fans of
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_5000_depth_2500_results.json
# insertion at 2370
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['8-26'], ['7-4'], ['7-12'], ['17-22'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['17-16'], ['21-16'], ['30-14'], ['6-30'], ['29-26'], ['14-18'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 1.9 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_5000_depth_5000_results.json
# insertion at 3000
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['8-26'], ['7-4'], ['7-12'], ['17-22'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['17-16'], ['21-16'], ['30-14'], ['29-26'], ['6-30'], ['14-18'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 1.9 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 100.0
# Response: There won't be a FIFA World Cup this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_5000_depth_7500_results.json
# There won't be a FIFA World Cup this year.
# [['16-19'], ['11-15'], ['6-9'], ['8-26'], ['7-4'], ['7-12'], ['17-22'], ['21-30'], ['11-2'], ['19-15'], ['24-29'], ['12-26'], ['21-16'], ['17-16'], ['30-14'], ['29-26'], ['6-30'], ['14-18'], ['21-4'], ['28-6']]
# -- Test Summary --
# Duration: 1.8 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 86.05624437332153
# Response: The FIFA World Cup will not be held this year.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_44/llama-2-7b-80k_irrelevant_id_44_len_5000_depth_10000_results.json
