# %% [markdown]
# # Notebook Overview
#
# This notebook provides an faster testing interface.
#
# It includes steps to
#  - Check GPU availability
#  - Set up the environment,
#  - Define helper functions,
#  - Run tests with a given **id** and **context_type**.
#
# The results are saved for further analysis.
#
# *Make sure to select the created `venv` as your kernel.*
#
# If there are any errors while running the tests, restart the the notebook, and run again.

# %% [markdown]
# ## Check GPU Availability
# Run this cell to check if there is free space on the gpu.
#
# If the **free space** is not close to the **total space** then someone else is probably using the machine.
#
# You can check the active processes bu running `nvidia-smi` in the terminal.

# %%
import torch

def get_gpu_memory_torch():
    if torch.cuda.is_available():
        for i in range(torch.cuda.device_count()):
            free_mem = torch.cuda.mem_get_info(i)[0] / 1024**3
            total_mem = torch.cuda.get_device_properties(i).total_memory / 1024**3
            print(f"GPU {i}: {free_mem:.4f} GiB free / {total_mem:.4f} GiB total")
    else:
        print("No CUDA-compatible GPU detected.")

get_gpu_memory_torch()
# Out:
# GPU 0: 22.8632 GiB free / 23.5766 GiB total

# %% [markdown]
# ## Setup
# The code below imports necessary modules, defines directory paths, and sets the Hugging Face cache path.
#
# **No need to modify this.**

# %%
import os
import sys
import json
from pathlib import Path

PROJECT_DIR = Path.cwd()
HAYSTACK_DIR = PROJECT_DIR / "haystack"
RELEVANT_DIR = HAYSTACK_DIR / "relevant"
IRRELAVANT_DIR = HAYSTACK_DIR / "irrelevant"
MISLEADING_IN_RELEVANT_DIR = HAYSTACK_DIR / "misleading_in_relevant"
MISLEADING_IN_IRRELEVANT_DIR = HAYSTACK_DIR / "misleading_in_irrelevant"

sys.path.append(str(PROJECT_DIR))

with open(HAYSTACK_DIR / "needles.json", "r") as f:
    NEEDLES_DATA = json.load(f)

# This sets the Hugging Face cache path. Make sure this directory exists. If not, refer to the README.
os.environ['HF_HOME'] = '.cache/hf_with_quota'

# %% [markdown]
# ## Helper Functions

# %%
from transformers import AutoTokenizer

def load_text(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

def insert_strings_at_sentence_breaks(text, insert_strings, context_length, tokenizer):
    # Step 1: Tokenize and truncate
    tokens = tokenizer.encode(text, add_special_tokens=False)[:context_length]
    
    # Step 2: Detect sentence breaks by decoding each token
    sentence_break_indices = [
        i for i, tok in enumerate(tokens)
        if tokenizer.decode([tok]).strip().endswith((".", "!", "?"))
    ]

    if len(sentence_break_indices) < len(insert_strings):
        raise ValueError(f"Only {len(sentence_break_indices)} sentence breaks found, "
                         f"but {len(insert_strings)} insertions requested.")

    # Step 3: Compute evenly spaced sentence break positions
    step = len(sentence_break_indices) // (len(insert_strings) + 1)
    insert_positions = [sentence_break_indices[(i + 1) * step] + 1 for i in range(len(insert_strings))]

    # Step 4: Insert insert_strings as tokens
    for pos, insert_str in reversed(list(zip(insert_positions, insert_strings))):
        insert_tokens = tokenizer.encode(insert_str, add_special_tokens=False)
        tokens[pos:pos] = insert_tokens

    return tokenizer.decode(tokens)


def insert_misleading_statements(filepath, insert_strings, context_length, output_path):
    """
    Insert misleading statements into the text at sentence breaks.
    Evenly distribute the misleading statements across the text within the context length.
    """
    tokenizer = AutoTokenizer.from_pretrained("yaofu/llama-2-7b-80k")

    full_text = load_text(filepath)
    modified_text = insert_strings_at_sentence_breaks(full_text, insert_strings, context_length, tokenizer)

    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(modified_text)

    print(f"✅ Output saved to {output_path}")

# %%
from argparse import Namespace

def get_haystack_file(item, context_type, with_misleading, context_length):
    """
    Get the haystack file for the given item and context type.
    Arguments:
        item (dict): The item to process.
        context_type (str): The type of context ("relevant" or "irrelevant").
        with_misleading (bool): Whether to include misleading information.
    Returns:
        str: The path to the haystack file.
    """

    if context_type == "relevant":
        original_dir = RELEVANT_DIR
        original_file = item["context_relevant"]  # Original file without misleading info
        misleading_dir = MISLEADING_IN_RELEVANT_DIR  # Output dir for the misleading file
    elif context_type == "irrelevant":
        original_dir = IRRELAVANT_DIR
        original_file = item["context_irrelevant"]
        misleading_dir = MISLEADING_IN_IRRELEVANT_DIR
    else:
        raise ValueError(f"Unknown context_type: {context_type}")

    if with_misleading:
        haystack_file = misleading_dir / original_file
        insert_misleading_statements(
            filepath=original_dir / original_file,           # Path to the original context file
            insert_strings=item["statements_misleading"],    # List of misleading statements
            context_length=context_length,                   # Max context length for insertion
            output_path=haystack_file                        # Output path for the processed file
        )
    else:
        haystack_file = original_dir / original_file

    return haystack_file

def get_args(id, context_type, with_misleading, data=NEEDLES_DATA):
    """
    Get the arguments for the given id and context type.
    Arguments:
        id (int): The id of the item.
        context_type (str): The type of context ("relevant" or "irrelevant").
        with_misleading (bool): Whether to include misleading information.
        data (list): The list of data items.
    Returns:
        Namespace: The arguments for the given id and context type.
    """

    context_length_max = 5000
    
    # find the item with the given id
    item = next(item for item in data if item["id"] == id)

    # get the haystack file for the given item and context type
    haystack_file = get_haystack_file(item, context_type, with_misleading, context_length_max)

    args = Namespace(
        model_name = "yaofu/llama-2-7b-80k",
        model_name_suffix = ( f"{context_type}_id_{item['id']}" if not with_misleading 
                             else f"{context_type}_id_{item['id']}_misleading"), # suffix used to name the results files,
        model_provider = "LLaMA",

        context_lengths_min = 0, # min context length
        context_lengths_max = context_length_max, # max context length
        context_lengths_num_intervals = 10, # number of intervals for context lengths

        document_depth_percent_intervals = 5, # number of intervals for document depth

        needle = item["needle_refined"],
        real_needle = item["real_needle"],
        retrieval_question = item["question_refined"],
        haystack_file = haystack_file,
    )

    return args

# %%
import gc
import torch
from retrieval_head_detection import LLMNeedleHaystackTester as RetrievalHeads

def cleanup(tester: RetrievalHeads):
    del tester.model_to_test
    del tester.testing_results
    del tester.head_counter
    del tester
    
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

def run_test(args):
    try:
        tester = RetrievalHeads(**vars(args))
        tester.start_test()
    finally:
        cleanup(tester)

# %% [markdown]
# ## Runing the Tests

# %% [markdown]
# ### Set up the test object:
# Specify the **id** and the **context_type** in the `get_args` function.
#
# If `with_misleading` is True, then misleading statements are added to the specified `context_type` file.

# %% [markdown]
# ### Start the Test
#
# Running the test will save:
#
# - **Contexts** → Given to the model per context length/depth
#   → `contexts/{model_name}_{context_type}_id_{id}`
#
# - **Results** → Model outputs per context length/depth
#   → `results/graph/{model_name}_{context_type}_id_{id}`
#
# **Example**:
# `results/graph/llama-2-7b-80k_relevant_id_44/`
#
# Each test should take <=5 minutes. It sometimes uses the CPU instead of the GPU, if it is taking longer to finish, then restart the notebook and run again.

# %%
# Example 1: Relevant context without misleading statements
args = get_args(id=160, context_type="irrelevant", with_misleading=True)
run_test(args)
# Out:
# ✅ Output saved to /cs/student/projects1/2021/aagarwal/SNLP_Project/haystack/misleading_in_irrelevant/160.txt
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# The model was loaded with use_flash_attention_2=True, which is deprecated and may be removed in a future release. Please use `attn_implementation="flash_attention_2"` instead.
# LlamaForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: The President of the United States is Donald Trump.
#
#
#
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.3 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_0_depth_0_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_0_depth_2500_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_0_depth_5000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_0_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_0_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_556_depth_0_results.json
# insertion at 73
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_556_depth_2500_results.json
# insertion at 154
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_556_depth_5000_results.json
# insertion at 254
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['14-18'], ['16-24'], ['7-4'], ['8-26'], ['11-15'], ['16-30'], ['17-0'], ['17-22'], ['21-27'], ['26-28'], ['6-9'], ['6-30'], ['12-26'], ['14-7']]
# -- Test Summary --
# Duration: 0.3 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_556_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['14-18'], ['7-4'], ['8-26'], ['11-15'], ['17-22'], ['6-9'], ['16-30'], ['21-27'], ['26-28'], ['6-30'], ['12-26'], ['14-7'], ['17-0']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_556_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 34.44713354110718
# Response: The President of the United States is the head of state and head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1111_depth_0_results.json
# insertion at 189
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1111_depth_2500_results.json
# insertion at 397
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1111_depth_5000_results.json
# insertion at 648
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1111_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['14-18'], ['7-4'], ['8-26'], ['11-15'], ['17-22'], ['6-9'], ['12-26'], ['20-28'], ['21-27'], ['26-28'], ['6-30'], ['14-7'], ['16-30']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1111_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['14-18'], ['16-24'], ['11-15'], ['8-26'], ['6-9'], ['7-4'], ['17-22'], ['21-27'], ['12-26'], ['14-7'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1667_depth_0_results.json
# insertion at 316
# Donald Trump
# [['16-19'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['14-18'], ['16-24'], ['6-9'], ['8-26'], ['7-4'], ['17-22'], ['21-27'], ['14-7'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1667_depth_2500_results.json
# insertion at 687
# Donald Trump
# [['16-19'], ['18-30'], ['19-15'], ['24-3'], ['11-15'], ['21-30'], ['31-16'], ['14-18'], ['16-24'], ['6-9'], ['8-26'], ['17-22'], ['21-27'], ['7-4'], ['14-7'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1667_depth_5000_results.json
# insertion at 1080
# Donald Trump
# [['16-19'], ['18-30'], ['19-15'], ['24-3'], ['11-15'], ['21-30'], ['31-16'], ['14-18'], ['16-24'], ['6-9'], ['8-26'], ['17-22'], ['21-27'], ['7-4'], ['14-7'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 2.4 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 52.97406315803528
# Response: The President of the United States is Donald Trump. After a new president is elected, they go through a solemn investiture ceremony called a passation des pouvoirs ("handing over of powers").
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1667_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['19-15'], ['24-3'], ['11-15'], ['21-30'], ['31-16'], ['14-18'], ['16-24'], ['6-9'], ['8-26'], ['17-22'], ['21-27'], ['7-4'], ['14-7'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_1667_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 33.09829235076904
# Response: The President of the United States is the head of state and the head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2222_depth_0_results.json
# insertion at 466
# Donald Trump
# -- Test Summary --
# Duration: 3.1 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 30.122655630111694
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term. The President is the commander-in-
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2222_depth_2500_results.json
# insertion at 1005
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2222_depth_5000_results.json
# insertion at 1468
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2222_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2222_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 30.122655630111694
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term. The President is the commander-in-
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2778_depth_0_results.json
# insertion at 623
# Donald Trump
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 30.122655630111694
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term. The President is the commander-in-
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2778_depth_2500_results.json
# insertion at 1247
# Donald Trump
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 30.122655630111694
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term. The President is the commander-in-
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2778_depth_5000_results.json
# insertion at 1920
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2778_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_2778_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3333_depth_0_results.json
# insertion at 742
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['14-7'], ['17-22'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3333_depth_2500_results.json
# insertion at 1512
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['21-27'], ['8-26'], ['17-22'], ['14-7'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3333_depth_5000_results.json
# insertion at 2341
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['17-22'], ['21-27'], ['8-26'], ['14-7'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3333_depth_7500_results.json
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['19-15'], ['24-3'], ['21-30'], ['31-16'], ['6-9'], ['14-18'], ['16-24'], ['17-22'], ['21-27'], ['8-26'], ['14-7'], ['7-4'], ['12-26'], ['20-28'], ['26-28'], ['6-30'], ['16-30']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3333_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.9 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 33.26294720172882
# Response: The President of the United States is the head of state and head of government of the United States. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3889_depth_0_results.json
# insertion at 883
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['24-3'], ['19-15'], ['21-30'], ['6-9'], ['31-16'], ['21-27'], ['14-18'], ['16-24'], ['17-22'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['12-26'], ['20-28'], ['26-28'], ['6-30']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3889_depth_2500_results.json
# insertion at 1808
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['24-3'], ['19-15'], ['21-30'], ['6-9'], ['31-16'], ['17-22'], ['21-27'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['12-26'], ['20-28'], ['26-28'], ['6-30']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 68.50568056106567
# Response: Donald Trump is the President of the United States.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3889_depth_5000_results.json
# insertion at 2738
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['24-3'], ['19-15'], ['21-30'], ['6-9'], ['31-16'], ['17-22'], ['21-27'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['12-26'], ['20-28'], ['26-28'], ['6-30']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3889_depth_7500_results.json
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['24-3'], ['19-15'], ['21-30'], ['6-9'], ['31-16'], ['17-22'], ['21-27'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['12-26'], ['20-28'], ['26-28'], ['6-30']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_3889_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['24-3'], ['19-15'], ['21-30'], ['6-9'], ['21-27'], ['31-16'], ['17-22'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['12-26'], ['20-27'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 68.50568056106567
# Response: Donald Trump is the President of the United States.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_4444_depth_0_results.json
# insertion at 1005
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['21-30'], ['21-27'], ['6-9'], ['17-22'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_4444_depth_2500_results.json
# insertion at 2089
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['21-30'], ['17-22'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_4444_depth_5000_results.json
# insertion at 3129
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_4444_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_4444_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_5000_depth_0_results.json
# insertion at 1195
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_5000_depth_2500_results.json
# insertion at 2362
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_5000_depth_5000_results.json
# insertion at 3578
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_5000_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['24-3'], ['19-15'], ['17-22'], ['21-30'], ['21-27'], ['6-9'], ['31-16'], ['14-18'], ['16-24'], ['8-26'], ['14-7'], ['7-4'], ['7-12'], ['20-27'], ['12-26'], ['20-28'], ['26-28']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160_misleading/llama-2-7b-80k_irrelevant_id_160_misleading_len_5000_depth_10000_results.json

# %%
# Example 2: Irrelevant context without misleading statements
args = get_args(id=160, context_type="irrelevant", with_misleading=False)
run_test(args)
# Out:
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: The President of the United States is Donald Trump.
#
#
#
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_0_depth_0_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_0_depth_2500_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_0_depth_5000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_0_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_0_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_556_depth_0_results.json
# insertion at 73
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_556_depth_2500_results.json
# insertion at 154
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_556_depth_5000_results.json
# insertion at 254
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['14-18'], ['16-24'], ['7-4'], ['8-26'], ['11-15'], ['16-30'], ['17-0'], ['17-22'], ['21-27'], ['26-28'], ['6-9'], ['6-30'], ['12-26'], ['14-7']]
# -- Test Summary --
# Duration: 0.3 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_556_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['14-18'], ['7-4'], ['8-26'], ['11-15'], ['17-22'], ['6-9'], ['16-30'], ['21-27'], ['26-28'], ['6-30'], ['12-26'], ['14-7'], ['17-0']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_556_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 34.44713354110718
# Response: The President of the United States is the head of state and head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1111_depth_0_results.json
# insertion at 189
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1111_depth_2500_results.json
# insertion at 397
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1111_depth_5000_results.json
# insertion at 648
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 30.986735224723816
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is directly elected by the people of the United States to a four-year term and is one of only two nationally elected federal
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1111_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['14-18'], ['7-4'], ['8-26'], ['11-15'], ['17-22'], ['6-9'], ['12-26'], ['20-28'], ['21-27'], ['26-28'], ['6-30'], ['14-7'], ['16-30']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1111_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1667_depth_0_results.json
# insertion at 316
# Donald Trump
# -- Test Summary --
# Duration: 2.8 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 33.26294720172882
# Response: The President of the United States is the head of state and head of government of the United States. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1667_depth_2500_results.json
# insertion at 687
# Donald Trump
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1667_depth_5000_results.json
# insertion at 1069
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['7-4'], ['11-15'], ['14-18'], ['8-26'], ['17-22'], ['6-9'], ['21-27'], ['6-30'], ['12-26'], ['14-7'], ['20-28'], ['26-28'], ['16-30']]
# -- Test Summary --
# Duration: 2.4 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 52.97406315803528
# Response: The President of the United States is Donald Trump. After a new president is elected, they go through a solemn investiture ceremony called a passation des pouvoirs ("handing over of powers").
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1667_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['16-24'], ['7-4'], ['11-15'], ['8-26'], ['17-22'], ['14-18'], ['6-9'], ['12-26'], ['20-28'], ['21-27'], ['6-30'], ['14-7'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_1667_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 33.09829235076904
# Response: The President of the United States is the head of state and the head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2222_depth_0_results.json
# insertion at 466
# Donald Trump
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 33.09829235076904
# Response: The President of the United States is the head of state and the head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2222_depth_2500_results.json
# insertion at 1005
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['11-15'], ['7-4'], ['16-24'], ['17-22'], ['8-26'], ['6-9'], ['14-18'], ['21-27'], ['6-30'], ['12-26'], ['14-7'], ['20-28'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2222_depth_5000_results.json
# insertion at 1501
# Donald Trump
# -- Test Summary --
# Duration: 3.1 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 36.574870347976685
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term. The President is the most powerful person in
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2222_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['31-16'], ['11-15'], ['7-4'], ['16-24'], ['17-22'], ['8-26'], ['6-9'], ['12-26'], ['14-18'], ['20-28'], ['21-27'], ['6-30'], ['14-7'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2222_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.2 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 33.26294720172882
# Response: The President of the United States is the head of state and head of government of the United States. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2778_depth_0_results.json
# insertion at 623
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['19-15'], ['24-3'], ['11-15'], ['31-16'], ['7-4'], ['17-22'], ['8-26'], ['16-24'], ['6-9'], ['21-27'], ['6-30'], ['12-26'], ['14-7'], ['14-18'], ['20-28'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2778_depth_2500_results.json
# insertion at 1236
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['24-3'], ['11-15'], ['19-15'], ['31-16'], ['17-22'], ['7-4'], ['8-26'], ['16-24'], ['6-9'], ['21-27'], ['6-30'], ['14-7'], ['14-18'], ['12-26'], ['20-28'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2778_depth_5000_results.json
# insertion at 1917
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['11-15'], ['24-3'], ['19-15'], ['7-4'], ['17-22'], ['31-16'], ['8-26'], ['6-9'], ['16-24'], ['21-27'], ['6-30'], ['14-7'], ['14-18'], ['12-26'], ['20-28'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2778_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['21-30'], ['11-15'], ['24-3'], ['19-15'], ['7-4'], ['17-22'], ['31-16'], ['8-26'], ['6-9'], ['16-24'], ['21-27'], ['6-30'], ['14-7'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_2778_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.1 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 33.09829235076904
# Response: The President of the United States is the head of state and the head of government of the United States of America.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3333_depth_0_results.json
# insertion at 742
# Donald Trump
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 33.74679386615753
# Response: The President of the United States is the head of state and the head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3333_depth_2500_results.json
# insertion at 1551
# Donald Trump
# -- Test Summary --
# Duration: 3.8 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 30.062130093574524
# Response: The President of the United States is the head of state and the head of government of the United States of America. The President is elected by the people of the United States to serve a four-year term and is one of only two people in the
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3333_depth_5000_results.json
# insertion at 2321
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['17-22'], ['31-16'], ['8-26'], ['6-9'], ['16-24'], ['21-27'], ['6-30'], ['14-7'], ['12-26'], ['14-18'], ['20-28'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3333_depth_7500_results.json
# Donald Trump
# [['16-19'], ['18-30'], ['11-15'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['17-22'], ['31-16'], ['8-26'], ['6-9'], ['16-24'], ['21-27'], ['6-30'], ['12-26'], ['14-7'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3333_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.1 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3889_depth_0_results.json
# insertion at 883
# Donald Trump
# -- Test Summary --
# Duration: 3.9 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The president leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3889_depth_2500_results.json
# insertion at 1819
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['8-26'], ['17-22'], ['31-16'], ['6-9'], ['21-27'], ['6-30'], ['16-24'], ['14-7'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3889_depth_5000_results.json
# insertion at 2739
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['8-26'], ['17-22'], ['31-16'], ['6-9'], ['21-27'], ['6-30'], ['14-7'], ['16-24'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3889_depth_7500_results.json
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['8-26'], ['17-22'], ['31-16'], ['6-9'], ['21-27'], ['6-30'], ['14-7'], ['16-24'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_3889_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.0 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 38.43095004558563
# Response: The President of the United States is the head of state of the United States.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_4444_depth_0_results.json
# insertion at 1005
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['19-15'], ['7-4'], ['8-26'], ['17-22'], ['31-16'], ['6-9'], ['21-27'], ['6-30'], ['14-7'], ['16-24'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_4444_depth_2500_results.json
# insertion at 2102
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['19-15'], ['8-26'], ['17-22'], ['7-4'], ['31-16'], ['6-9'], ['6-30'], ['21-27'], ['14-7'], ['16-24'], ['12-26'], ['20-28'], ['14-18'], ['26-28'], ['20-27']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_4444_depth_5000_results.json
# insertion at 3150
# Donald Trump
# [['16-19'], ['11-15'], ['21-30'], ['18-30'], ['24-3'], ['19-15'], ['17-22'], ['8-26'], ['7-4'], ['6-9'], ['31-16'], ['6-30'], ['21-27'], ['14-7'], ['16-24'], ['12-26'], ['20-28'], ['14-18'], ['20-27'], ['26-28']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_4444_depth_7500_results.json
# Donald Trump
# [['16-19'], ['11-15'], ['21-30'], ['18-30'], ['24-3'], ['19-15'], ['17-22'], ['8-26'], ['7-4'], ['31-16'], ['6-9'], ['6-30'], ['21-27'], ['14-7'], ['16-24'], ['20-28'], ['12-26'], ['14-18'], ['20-27'], ['26-28']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_4444_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.4 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 34.41890478134155
# Response: The President of the United States is the head of state and head of government of the United States of America. The President leads the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_5000_depth_0_results.json
# insertion at 1195
# Donald Trump
# [['16-19'], ['11-15'], ['21-30'], ['18-30'], ['24-3'], ['17-22'], ['19-15'], ['8-26'], ['7-4'], ['6-9'], ['31-16'], ['6-30'], ['21-27'], ['14-7'], ['16-24'], ['20-28'], ['12-26'], ['14-18'], ['20-27'], ['26-28']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_5000_depth_2500_results.json
# insertion at 2393
# Donald Trump
# -- Test Summary --
# Duration: 4.3 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 31.532174348831177
# Response: The President of the United States is the head of state and head of government of the United States of America. The President is the commander-in-chief of the United States Armed Forces. The President is also the head of the executive branch
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_5000_depth_5000_results.json
# insertion at 3587
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['17-22'], ['19-15'], ['8-26'], ['7-4'], ['6-9'], ['31-16'], ['6-30'], ['21-27'], ['14-7'], ['16-24'], ['20-28'], ['12-26'], ['14-18'], ['7-12'], ['20-27']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_5000_depth_7500_results.json
# Donald Trump
# [['16-19'], ['11-15'], ['18-30'], ['21-30'], ['24-3'], ['17-22'], ['19-15'], ['8-26'], ['7-4'], ['6-9'], ['31-16'], ['21-27'], ['6-30'], ['14-7'], ['16-24'], ['20-28'], ['12-26'], ['14-18'], ['20-27'], ['26-28']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_irrelevant_id_160/llama-2-7b-80k_irrelevant_id_160_len_5000_depth_10000_results.json

# %%
# Exmample 3: Relevant context with misleading statements
args = get_args(id=160, context_type="relevant", with_misleading=True)
run_test(args)
# Out:
# ✅ Output saved to /cs/student/projects1/2021/aagarwal/SNLP_Project/haystack/misleading_in_relevant/160.txt
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: The President of the United States is Donald Trump.
#
#
#
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_0_depth_0_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_0_depth_2500_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_0_depth_5000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_0_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_0_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_556_depth_0_results.json
# insertion at 83
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_556_depth_2500_results.json
# insertion at 162
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 33.70937705039978
# Response: The President of the United States is the head of state and head of government of the United States of America. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_556_depth_5000_results.json
# insertion at 242
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_556_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_556_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1111_depth_0_results.json
# insertion at 221
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1111_depth_2500_results.json
# insertion at 441
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1111_depth_5000_results.json
# insertion at 654
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.9 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 59.86025929450989
# Response: The President of the United States is Donald Trump. Donald Trump is the 47th and current president since January 20, 2025.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1111_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1111_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 33.70937705039978
# Response: The President of the United States is the head of state and head of government of the United States of America. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1667_depth_0_results.json
# insertion at 363
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1667_depth_2500_results.json
# insertion at 677
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.5 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1667_depth_5000_results.json
# insertion at 1067
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 53.3666729927063
# Response: The President of the United States is Donald Trump. The members of Congress elected a president of the United States in Congress Assembled to preside over its deliberation as a neutral discussion moderator. Unrelated to and quite dissimilar from the later
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1667_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_1667_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.0 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2222_depth_0_results.json
# insertion at 500
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2222_depth_2500_results.json
# insertion at 970
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2222_depth_5000_results.json
# insertion at 1456
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2222_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2222_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2778_depth_0_results.json
# insertion at 619
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2778_depth_2500_results.json
# insertion at 1263
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.7 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2778_depth_5000_results.json
# insertion at 1899
# Donald Trump
# -- Test Summary --
# Duration: 3.4 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 44.43291425704956
# Response: Donald Trump. Roosevelt's New Deal programs were unprecedented in scope and power, and he was able to get Congress to pass most of his proposals. Roosevelt's successors, Harry S.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2778_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_2778_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3333_depth_0_results.json
# insertion at 752
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3333_depth_2500_results.json
# insertion at 1523
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3333_depth_5000_results.json
# insertion at 2310
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3333_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3333_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.0 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3889_depth_0_results.json
# insertion at 895
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3889_depth_2500_results.json
# insertion at 1779
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3889_depth_5000_results.json
# insertion at 2745
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3889_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_3889_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.1 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_4444_depth_0_results.json
# insertion at 1035
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 68.50568056106567
# Response: Donald Trump is the President of the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_4444_depth_2500_results.json
# insertion at 2100
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 68.50568056106567
# Response: Donald Trump is the President of the United States.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_4444_depth_5000_results.json
# insertion at 3140
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_4444_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_4444_depth_10000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['18-30'], ['16-24'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_5000_depth_0_results.json
# insertion at 1165
# Donald Trump
# [['14-18'], ['16-19'], ['18-30'], ['16-24'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_5000_depth_2500_results.json
# insertion at 2345
# Donald Trump
# [['14-18'], ['16-19'], ['18-30'], ['16-24'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_5000_depth_5000_results.json
# insertion at 3572
# Donald Trump
# [['14-18'], ['16-19'], ['18-30'], ['16-24'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_5000_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['18-30'], ['16-24'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['11-15'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160_misleading/llama-2-7b-80k_relevant_id_160_misleading_len_5000_depth_10000_results.json

# %%
# Example 4: Irrelevant context with misleading statements
args = get_args(id=160, context_type="relevant", with_misleading=False)
run_test(args)
# Out:
# loading from yaofu/llama-2-7b-80k
# layer number: 32, head number 32
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Starting Needle In A Haystack Testing...
# - Model: yaofu/llama-2-7b-80k
# - Context Lengths: 10, Min: 0, Max: 5000
# - Document Depths: 5, Min: 0%, Max: 100%
# - Needle: The President of the United States is Donald Trump.
#
#
#
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 0%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_0_depth_0_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 25%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_0_depth_2500_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 50%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_0_depth_5000_results.json
# insertion at 0
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_0_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.2 seconds
# Context: 0 tokens
# Depth: 100%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_0_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_556_depth_0_results.json
# insertion at 83
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_556_depth_2500_results.json
# insertion at 162
# Donald Trump
# -- Test Summary --
# Duration: 2.2 seconds
# Context: 556 tokens
# Depth: 50%
# Score: 33.70937705039978
# Response: The President of the United States is the head of state and head of government of the United States of America. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_556_depth_5000_results.json
# insertion at 242
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_556_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.6 seconds
# Context: 556 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_556_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1111_depth_0_results.json
# insertion at 221
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1111_depth_2500_results.json
# insertion at 441
# Donald Trump
# -- Test Summary --
# Duration: 2.7 seconds
# Context: 1111 tokens
# Depth: 50%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1111_depth_5000_results.json
# insertion at 666
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1111_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.8 seconds
# Context: 1111 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1111_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1667_depth_0_results.json
# insertion at 363
# Donald Trump
# -- Test Summary --
# Duration: 2.9 seconds
# Context: 1667 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1667_depth_2500_results.json
# insertion at 666
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1667_depth_5000_results.json
# insertion at 1086
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1667_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 0.9 seconds
# Context: 1667 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_1667_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.0 seconds
# Context: 2222 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2222_depth_0_results.json
# insertion at 500
# Donald Trump
# -- Test Summary --
# Duration: 3.0 seconds
# Context: 2222 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2222_depth_2500_results.json
# insertion at 1003
# Donald Trump
# -- Test Summary --
# Duration: 3.0 seconds
# Context: 2222 tokens
# Depth: 50%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2222_depth_5000_results.json
# insertion at 1445
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2222_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.0 seconds
# Context: 2222 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2222_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2778_depth_0_results.json
# insertion at 619
# Donald Trump
# -- Test Summary --
# Duration: 3.3 seconds
# Context: 2778 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2778_depth_2500_results.json
# insertion at 1280
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2778_depth_5000_results.json
# insertion at 1909
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2778_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.1 seconds
# Context: 2778 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_2778_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 3.7 seconds
# Context: 3333 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3333_depth_0_results.json
# insertion at 741
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 25%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3333_depth_2500_results.json
# insertion at 1554
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3333_depth_5000_results.json
# insertion at 2323
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3333_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.3 seconds
# Context: 3333 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3333_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.0 seconds
# Context: 3889 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3889_depth_0_results.json
# insertion at 884
# Donald Trump
# -- Test Summary --
# Duration: 3.9 seconds
# Context: 3889 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3889_depth_2500_results.json
# insertion at 1833
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.5 seconds
# Context: 3889 tokens
# Depth: 50%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3889_depth_5000_results.json
# insertion at 2736
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3889_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.4 seconds
# Context: 3889 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_3889_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.1 seconds
# Context: 4444 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_4444_depth_0_results.json
# insertion at 1056
# Donald Trump
# -- Test Summary --
# Duration: 4.1 seconds
# Context: 4444 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_4444_depth_2500_results.json
# insertion at 2108
# Donald Trump
# -- Test Summary --
# Duration: 4.1 seconds
# Context: 4444 tokens
# Depth: 50%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_4444_depth_5000_results.json
# insertion at 3173
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 75%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_4444_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.6 seconds
# Context: 4444 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_4444_depth_10000_results.json
# insertion at 0
# Donald Trump
# -- Test Summary --
# Duration: 4.3 seconds
# Context: 5000 tokens
# Depth: 0%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_5000_depth_0_results.json
# insertion at 1193
# Donald Trump
# -- Test Summary --
# Duration: 4.3 seconds
# Context: 5000 tokens
# Depth: 25%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_5000_depth_2500_results.json
# insertion at 2383
# Donald Trump
# -- Test Summary --
# Duration: 4.3 seconds
# Context: 5000 tokens
# Depth: 50%
# Score: 32.3879599571228
# Response: The President of the United States is the head of state and head of government of the United States. The president directs the executive branch of the federal government and is the commander-in-chief of the United States Armed Forces.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_5000_depth_5000_results.json
# insertion at 3545
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.2 seconds
# Context: 5000 tokens
# Depth: 75%
# Score: 92.32540130615234
# Response: Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_5000_depth_7500_results.json
# Donald Trump
# [['14-18'], ['16-19'], ['16-24'], ['18-30'], ['19-15'], ['21-30'], ['24-3'], ['31-16'], ['6-9'], ['6-30'], ['7-4'], ['8-26'], ['11-15'], ['12-26'], ['14-7'], ['16-5'], ['16-30'], ['16-31'], ['17-0'], ['17-18']]
# -- Test Summary --
# Duration: 1.7 seconds
# Context: 5000 tokens
# Depth: 100%
# Score: 70.5931007862091
# Response: The President of the United States is Donald Trump.
#
# Writing at results/graph/llama-2-7b-80k_relevant_id_160/llama-2-7b-80k_relevant_id_160_len_5000_depth_10000_results.json
